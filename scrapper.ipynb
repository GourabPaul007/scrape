# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
lawsUrl = "https://indiankanoon.org/browselaws/"
response_lawsUrl = requests.get(lawsUrl)

soup_browse_laws = BeautifulSoup(response_lawsUrl.content, 'html.parser')
browse_laws_urls = []
browse_laws_hrefs = soup_browse_laws.select('div[class="info_indian_kanoon"] td a')
for each_laws_href in browse_laws_hrefs:
    browse_laws_urls.append("https://indiankanoon.org"+each_laws_href['href'])
print(browse_laws_urls)

india_laws = browse_laws_urls[0:4]
state_laws = browse_laws_urls[4:43]
british_laws = browse_laws_urls[43:]
print(india_laws)
# Out:
# ['https://indiankanoon.org/browse/union-act/', 'https://indiankanoon.org/browse/constitution-amendments/', 'https://indiankanoon.org/browse/un-convention/', 'https://indiankanoon.org/browse/treaty-act/', 'https://indiankanoon.org/browse/andhra-act/', 'https://indiankanoon.org/browse/arunachal-act/', 'https://indiankanoon.org/browse/assam-act/', 'https://indiankanoon.org/browse/bihar-act/', 'https://indiankanoon.org/browse/chandigarh-act/', 'https://indiankanoon.org/browse/chattisgarh-act/', 'https://indiankanoon.org/browse/delhi-act/', 'https://indiankanoon.org/browse/goa-act/', 'https://indiankanoon.org/browse/gujarat-act/', 'https://indiankanoon.org/browse/haryana-act/', 'https://indiankanoon.org/browse/himachal-act/', 'https://indiankanoon.org/browse/jk-act/', 'https://indiankanoon.org/browse/jharkhand-act/', 'https://indiankanoon.org/browse/karnataka-act/', 'https://indiankanoon.org/browse/kerala-act/', 'https://indiankanoon.org/browse/madhyabharat-act/', 'https://indiankanoon.org/browse/mp-act/', 'https://indiankanoon.org/browse/mh-act/', 'https://indiankanoon.org/browse/manipur-act/', 'https://indiankanoon.org/browse/meghalaya-act/', 'https://indiankanoon.org/browse/mizoram-act/', 'https://indiankanoon.org/browse/nagaland-act/', 'https://indiankanoon.org/browse/odisha-act/', 'https://indiankanoon.org/browse/puducherry-act/', 'https://indiankanoon.org/browse/punjab-act/', 'https://indiankanoon.org/browse/rajasthan-act/', 'https://indiankanoon.org/browse/sikkim-act/', 'https://indiankanoon.org/browse/tn-act/', 'https://indiankanoon.org/browse/telengana-act/', 'https://indiankanoon.org/browse/tripura-act/', 'https://indiankanoon.org/browse/uttarakhand-act/', 'https://indiankanoon.org/browse/up-act/', 'https://indiankanoon.org/browse/wb-act/', 'https://indiankanoon.org/browse/lakshadweep-act/', 'https://indiankanoon.org/browse/andaman-act/', 'https://indiankanoon.org/browse/bengaluru-act/', 'https://indiankanoon.org/browse/ladakh-act/', 'https://indiankanoon.org/browse/daman-act/', 'https://indiankanoon.org/browse/dadra-act/', 'https://indiankanoon.org/browse/british-act/', 'https://indiankanoon.org/browse/bhopal-act/', 'https://indiankanoon.org/browse/bombay-act/', 'https://indiankanoon.org/browse/madras-act/', 'https://indiankanoon.org/browse/centralprovinces-act/', 'https://indiankanoon.org/browse/bengalpresidency-act/', 'https://indiankanoon.org/browse/chotanagpur-act/', 'https://indiankanoon.org/browse/mysore-act/', 'https://indiankanoon.org/browse/nagpurprovince-act/', 'https://indiankanoon.org/browse/britishpunjab-act/', 'https://indiankanoon.org/browse/utdprovinces-act/', 'https://indiankanoon.org/browse/vindhya-act/']
# ['https://indiankanoon.org/browse/union-act/', 'https://indiankanoon.org/browse/constitution-amendments/', 'https://indiankanoon.org/browse/un-convention/', 'https://indiankanoon.org/browse/treaty-act/']
# union-act
# constitution-amendments
# un-convention
# treaty-act

# %%
# creating folders
import os

for each_law in india_laws:
    if not os.path.exists(each_law):
        folder_name = each_law.split('/')[-2]
        os.makedirs("india_laws/"+folder_name)

for each_law in state_laws:
    if not os.path.exists(each_law):
        folder_name = each_law.split('/')[-2]
        os.makedirs("state_laws/"+folder_name)

for each_law in british_laws:
    if not os.path.exists(each_law):
        folder_name = each_law.split('/')[-2]
        os.makedirs("british_laws/"+folder_name)

# %%
for each_law in india_laws:
    # print(each_law)
    response_each_law = requests.get(each_law)
    soup_each_law = BeautifulSoup(response_each_law.content, 'html.parser')
    law_urls = soup_each_law.select('div[class="info_indian_kanoon"] td a')
    for each_law_url in law_urls:
        folder = each_law_url['href'].split('/')[2]
        file_path = "./india_laws/"+folder+"/"
        url = "https://indiankanoon.org"+each_law_url['href']
        print(url)
        print(file_path)
        response_all_year = requests.get(url)
        # response_law_url = requests.get(each_law_url['href'])
        # soup_law_url = BeautifulSoup(response_law_url.content, 'html.parser')
        # law_url_titles = soup_law_url.select('div[class="info_indian_kanoon"] td a')
        # for each_law_url_title in law_url_titles:
        #     print(each_law_url_title.text)
# Out:
# https://indiankanoon.org/browse/union-act/1074/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1800/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1838/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1849/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1850/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1851/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1855/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1856/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1857/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1859/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1860/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1861/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1862/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1863/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1864/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1865/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1866/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1867/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1869/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1870/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1871/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1872/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1873/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1874/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1875/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1876/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1878/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1879/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1881/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1882/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1883/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1884/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1885/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1886/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1887/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1888/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1890/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1891/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1892/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1893/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1895/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1897/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1898/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1899/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1901/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1903/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1904/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1905/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1906/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1908/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1909/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1910/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1911/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1912/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1913/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1914/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1915/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1916/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1917/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1918/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1919/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1920/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1921/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1922/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1923/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1924/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1925/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1926/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1927/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1928/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1929/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1930/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1931/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1932/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1933/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1934/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1935/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1936/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1937/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1938/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1939/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1940/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1941/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1942/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1943/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1944/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1945/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1946/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1947/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1948/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1949/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1950/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1951/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1952/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1953/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1954/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1955/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1956/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1957/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1958/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1959/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1960/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1961/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1962/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1963/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1964/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1965/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1966/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1967/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1968/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1969/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1970/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1971/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1972/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1973/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1974/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1975/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1976/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1977/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1978/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1979/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1980/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1981/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1982/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1983/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1984/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1985/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1986/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1987/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1988/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1989/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1990/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1991/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1992/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1993/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1994/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1995/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1996/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1997/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1998/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/1999/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2000/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2001/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2002/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2003/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2004/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2005/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2006/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2007/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2008/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2009/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2010/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2011/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2012/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2013/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2014/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2015/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2016/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2017/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2018/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2019/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2020/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2021/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2022/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2023/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2024/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/union-act/2066/
# ./india_laws/union-act/
# https://indiankanoon.org/browse/constitution-amendments/1950/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1951/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1953/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1955/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1956/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1960/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1961/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1962/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1963/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1964/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1966/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1967/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1969/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1970/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1971/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1972/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1973/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1974/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1975/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1976/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1978/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1979/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1980/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1983/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1984/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1985/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1986/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1987/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1988/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1989/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1990/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1991/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1992/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1993/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1994/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/1995/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2000/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2002/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2003/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2004/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2006/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2010/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2011/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2012/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2013/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2014/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2015/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2016/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2018/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2019/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2021/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/constitution-amendments/2023/
# ./india_laws/constitution-amendments/
# https://indiankanoon.org/browse/un-convention/1965/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/1967/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/1976/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/1981/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/1990/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/2000/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/2008/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/un-convention/2010/
# ./india_laws/un-convention/
# https://indiankanoon.org/browse/treaty-act/1800/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1883/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1886/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1939/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1960/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1963/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1971/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1972/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1975/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1981/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1992/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1993/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1994/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1996/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1998/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/1999/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2000/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2002/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2003/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2004/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2005/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2006/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2007/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2008/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2009/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2010/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2011/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2012/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2013/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2015/
# ./india_laws/treaty-act/
# https://indiankanoon.org/browse/treaty-act/2019/
# ./india_laws/treaty-act/

# %%
# url = 'https://indiankanoon.org/browse/union-act/1074/'
url = 'https://indiankanoon.org/browse/union-act/1960/'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'html.parser')
# Get the "entire year" link
entire_year_link = soup.select('div[class="info_indian_kanoon"] tr:nth-of-type(1) td a')[0]
response_all_year_first_page = requests.get('https://indiankanoon.org' + entire_year_link["href"])

result_links = set()
soup_all_year_first_page = BeautifulSoup(response_all_year_first_page.content, 'html.parser')
all_year_links_first_page = soup_all_year_first_page.select('div[class="result"] > div[class="result_title"] > a')
for each_link_in_first_page in all_year_links_first_page:
    result_links.add(f"https://indiankanoon.org{each_link_in_first_page["href"]}")

# getting the other pages if pagination exists
all_year_links_other_pages = soup_all_year_first_page.select('div[class="bottom"] > span[class="pagenum"] > a')
for link in all_year_links_other_pages:
    each_page_url = "https://indiankanoon.org"+link['href']
    print(each_page_url)
    response_all_year_other_page = requests.get(each_page_url)
    soup_all_year_other_page = BeautifulSoup(response_all_year_other_page.content, 'html.parser')
    all_year_links_other_page = soup_all_year_other_page.select('div[class="result"] > div[class="result_title"] > a')
    for each_link_in_other_page in all_year_links_other_page:
        result_links.add(f"https://indiankanoon.org{each_link_in_other_page["href"]}")
# Out:
# https://indiankanoon.org/search/?formInput=doctypes%3A%20union-act%20fromdate%3A%201-1-1960%20todate%3A%2031-12-1960&pagenum=1
# https://indiankanoon.org/search/?formInput=doctypes%3A%20union-act%20fromdate%3A%201-1-1960%20todate%3A%2031-12-1960&pagenum=2
# https://indiankanoon.org/search/?formInput=doctypes%3A%20union-act%20fromdate%3A%201-1-1960%20todate%3A%2031-12-1960&pagenum=3

# %%
print(result_links)
print(len(result_links))
# Out:
# {'https://indiankanoon.org/doc/18869497/', 'https://indiankanoon.org/doc/84563256/', 'https://indiankanoon.org/doc/101006637/', 'https://indiankanoon.org/doc/51266069/', 'https://indiankanoon.org/doc/163287771/', 'https://indiankanoon.org/doc/148841989/', 'https://indiankanoon.org/doc/138256172/', 'https://indiankanoon.org/doc/193333732/', 'https://indiankanoon.org/doc/196613330/', 'https://indiankanoon.org/doc/190103413/', 'https://indiankanoon.org/doc/191541151/', 'https://indiankanoon.org/doc/12701612/', 'https://indiankanoon.org/doc/1973522/', 'https://indiankanoon.org/doc/32319495/', 'https://indiankanoon.org/doc/46115842/', 'https://indiankanoon.org/doc/26699763/', 'https://indiankanoon.org/doc/162888952/', 'https://indiankanoon.org/doc/1488142/', 'https://indiankanoon.org/doc/34628406/', 'https://indiankanoon.org/doc/93870527/', 'https://indiankanoon.org/doc/11585441/', 'https://indiankanoon.org/doc/155496595/', 'https://indiankanoon.org/doc/175170794/', 'https://indiankanoon.org/doc/965818/', 'https://indiankanoon.org/doc/1954823/', 'https://indiankanoon.org/doc/676326/', 'https://indiankanoon.org/doc/32779956/', 'https://indiankanoon.org/doc/1926537/', 'https://indiankanoon.org/doc/452163/', 'https://indiankanoon.org/doc/177474312/', 'https://indiankanoon.org/doc/12169897/', 'https://indiankanoon.org/doc/21222718/', 'https://indiankanoon.org/doc/310908/', 'https://indiankanoon.org/doc/180565020/', 'https://indiankanoon.org/doc/1759043/', 'https://indiankanoon.org/doc/922600/', 'https://indiankanoon.org/doc/176682720/', 'https://indiankanoon.org/doc/172079496/', 'https://indiankanoon.org/doc/145229992/'}
# 39

# %%
import requests
from bs4 import BeautifulSoup
import json

url = 'https://indiankanoon.org/doc/51266069/'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
hidden_tags = soup.find_all("input", type="hidden", value="pdf")
a = hidden_tags[0].parent
print(a)
# action = soup.find('form', id='form_product_page').get('action')
headers={}
ac = a.get("action")
pdfResponse = requests.post("https://indiankanoon.org" + ac, headers=headers, data = {'type': 'pdf'})
print(pdfResponse.headers)
# for tag in hidden_tags:
#       print(tag)
# Out:
# <form action="/doc/161770412/" method="POST">
# <input name="type" type="hidden" value="pdf"/>
# <button id="pdfdoc" type="submit">Get this document in PDF</button>
# </form>
# {'Date': 'Thu, 14 Mar 2024 09:32:15 GMT', 'Content-Type': 'application/pdf', 'Content-Length': '251222', 'Connection': 'keep-alive', 'Content-Disposition': 'attachment; filename="Banking_Companies_Act_1949.PDF"', 'Vary': 'Cookie', 'CF-Cache-Status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=Oylvkwl3Koc78jULgfwzgnyY4diazkHVvgePbtAhbyVh6VVnFsarxcp2RiFDM7in7sRhDPzgttLiwFVnOLZ8FC7pJdQMVouUvqNMWH0OYIad8trWh1nYSdvS2U4XrxipPlw%3D"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '86434160282747ba-BOM'}

# %%
import re
d = pdfResponse.headers['content-disposition']
fname = re.findall("filename=(.+)", d)[0].replace('"','')
print(fname)

# with open(f'./{fname}', 'wb') as f:
#     f.write(pdfResponse.content)

from pathlib import Path
filename = Path(f'{fname}')
filename.write_bytes(pdfResponse.content)
# Out:
# Banking_Companies_Act_1949.PDF
# 251222
